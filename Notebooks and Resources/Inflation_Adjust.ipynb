# %%
import pandas as pd

# %%
movieDF = pd.read_csv('US_movies_cleanup.csv')
movieDF.head()
# Out:
#    Unnamed: 0                               Title Runtime (mins)  Year  \
# 0           0                        Pulp Fiction        154 min  1994
# 1           1            The Amazing Spider-Man 2        142 min  2014
# 2           2            The Shawshank Redemption        142 min  1994
# 3           3  Star Wars: Episode IV - A New Hope        121 min  1977
# 4           4                  Back to the Future        116 min  1985
#
#   Release Date                               Genre  IMDb Rating  Num Votes  \
# 0  14 Oct 1994                        Crime, Drama          8.9  1,645,131
# 1  02 May 2014           Action, Adventure, Sci-Fi          6.6    388,759
# 2  14 Oct 1994                               Drama          9.3  2,099,597
# 3  25 May 1977  Action, Adventure, Fantasy, Sci-Fi          8.6  1,123,397
# 4  03 Jul 1985           Adventure, Comedy, Sci-Fi          8.5    938,445
#
#   Rotten Tomatoes Rating  Metascore    Box Office  Rated          Production  \
# ...

# %%
movieDF.dtypes
# Out:
# Unnamed: 0                  int64
# Title                     float64
# Runtime (mins)             object
# Year                       object
# Release Date               object
# Genre                      object
# IMDb Rating               float64
# Num Votes                  object
# Rotten Tomatoes Rating     object
# Metascore                 float64
# Box Office                 object
# Rated                      object
# Production                 object
# Director                   object
# Actor                      object
# dtype: object

# %%
# change datatype of Title
movieDF.Title = movieDF.Title.astype('str')

# %%
movieDF.head()
# Out:
#    Unnamed: 0                               Title Runtime (mins)  Year  \
# 0           0                        Pulp Fiction        154 min  1994
# 1           1            The Amazing Spider-Man 2        142 min  2014
# 2           2            The Shawshank Redemption        142 min  1994
# 3           3  Star Wars: Episode IV - A New Hope        121 min  1977
# 4           4                  Back to the Future        116 min  1985
#
#   Release Date                               Genre  IMDb Rating  Num Votes  \
# 0  14 Oct 1994                        Crime, Drama          8.9  1,645,131
# 1  02 May 2014           Action, Adventure, Sci-Fi          6.6    388,759
# 2  14 Oct 1994                               Drama          9.3  2,099,597
# 3  25 May 1977  Action, Adventure, Fantasy, Sci-Fi          8.6  1,123,397
# 4  03 Jul 1985           Adventure, Comedy, Sci-Fi          8.5    938,445
#
#   Rotten Tomatoes Rating  Metascore    Box Office  Rated          Production  \
# ...

# %%
# uppercase titles, remove punctuations and spaces
movieDF.Title = movieDF['Title'].str.upper()
movieDF.Title = movieDF.Title.replace(':','')
movieDF.Title = movieDF.Title.replace('-','')
movieDF.head()
# Out:
#    Unnamed: 0                               Title Runtime (mins)  Year  \
# 0           0                        PULP FICTION        154 min  1994
# 1           1            THE AMAZING SPIDER-MAN 2        142 min  2014
# 2           2            THE SHAWSHANK REDEMPTION        142 min  1994
# 3           3  STAR WARS: EPISODE IV - A NEW HOPE        121 min  1977
# 4           4                  BACK TO THE FUTURE        116 min  1985
#
#   Release Date                               Genre  IMDb Rating  Num Votes  \
# 0  14 Oct 1994                        Crime, Drama          8.9  1,645,131
# 1  02 May 2014           Action, Adventure, Sci-Fi          6.6    388,759
# 2  14 Oct 1994                               Drama          9.3  2,099,597
# 3  25 May 1977  Action, Adventure, Fantasy, Sci-Fi          8.6  1,123,397
# 4  03 Jul 1985           Adventure, Comedy, Sci-Fi          8.5    938,445
#
#   Rotten Tomatoes Rating  Metascore    Box Office  Rated          Production  \
# ...

# %%
# pull box office data
# pagination list
mojoDF = pd.read_csv('annual_mojo.csv')
mojoDF.head()
mojoDF.title
# Out:
# 0                      Indiana Jones and the Last Crusade
# 1                                                  Batman
# 2                              Back to the Future Part II
# 3                                       Look Whos Talking
# 4                                      Dead Poets Society
# 5                                         Lethal Weapon 2
# 6                                 Honey I Shrunk the Kids
# 7                                         Ghostbusters II
# 8                                      The Little Mermaid
# 9                              Born on the Fourth of July
# 10                                   The War of the Roses
# 11                                        Licence to Kill
# 12                                     Driving Miss Daisy
# 13                                             Black Rain
# 14                                             Parenthood
# 15                                            Sea of Love
# ...
